# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # load data file using Pandas

# %%
df = pd.read_csv(r"C:\Users\auxte\Downloads\1569582940_googleplaystore (1)\googleplaystore.csv")

# %%
print(df.isnull())
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
#Checking Null Values  in each coloumn
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#Checking data type of each column
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#Drop records with nulls in any of the columns. 
df_clean=df.dropna()

# %%
import re

# %%
# Variables seem to have incorrect type and inconsistent formatting. You need to fix them: 
def convert_size(Size):
    if isinstance(Size, str):
        if 'k' in Size.lower() or 'k' in Size:
            return float(Size.replace('k', '').replace('K', '')) / 1024  # Convert KB to MB
        elif 'm' in Size.lower():
            return float(Size.replace('M', '').replace('m', ''))
        elif Size == 'Varies with device':
            return 'nan'
    return Size

# %%
df_clean
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_clean['Size']=df_clean['Size'].apply(convert_size)
# Out:
# C:\Users\auxte\AppData\Local\Temp\ipykernel_21228\3902577058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Size']=df_clean['Size'].apply(convert_size)

# %%
print(df_clean['Size'].describe())
# Out:
# count     9360
# unique     412
# top        nan
# freq      1637
# Name: Size, dtype: object

# %%
df_clean
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Reviews is a numeric field that is loaded as a string field. Convert it to numeric (int/float).
pd.to_numeric(df_clean['Reviews'], errors = 'coerce')
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10834         7
# 10836        38
# 10837         4
# 10839       114
# 10840    398307
# Name: Reviews, Length: 9360, dtype: int64

# %%
df_clean['Installs'] = df_clean['Installs'].str.replace('+', '').str.replace(',', '')
df_clean['Installs'] = pd.to_numeric(df_clean['Installs'], errors='coerce')
# Out:
# C:\Users\auxte\AppData\Local\Temp\ipykernel_21228\2288582072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Installs'] = df_clean['Installs'].str.replace('+', '').str.replace(',', '')
# C:\Users\auxte\AppData\Local\Temp\ipykernel_21228\2288582072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Installs'] = pd.to_numeric(df_clean['Installs'], errors='coerce')

# %%
#Price field is a string and has $ symbol. Remove ‘$’ sign, and convert it to numeric.
df_clean['Price'] = df_clean['Price'].str.replace('$','')
df_clean['Price'] = pd.to_numeric(df_clean['Price'], errors = 'coerce')
# Out:
# C:\Users\auxte\AppData\Local\Temp\ipykernel_21228\2688155308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Price'] = df_clean['Price'].str.replace('$','')
# C:\Users\auxte\AppData\Local\Temp\ipykernel_21228\2688155308.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Price'] = pd.to_numeric(df_clean['Price'], errors = 'coerce')

# %%
invalid_ratings = df_clean[(df_clean['Rating'] < 1) | (df_clean['Rating'] > 5)]
print(f"Records with invalid ratings: {len(invalid_ratings)}")
df_clean = df_clean[(df_clean['Rating'] >= 1) & (df_clean['Rating'] <= 5)]
# Out:
# Records with invalid ratings: 0

# %%
def clean_reviews_installs(df):
    # Convert to numeric, forcing non-numeric to NaN
    df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')
    df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')
    
    # Drop rows where either column is NaN
    initial_count = len(df)
    df = df.dropna(subset=['Reviews', 'Installs'])
    print(f"Dropped {initial_count - len(df)} rows with missing values")
    
    # Find and remove invalid records
    invalid = df[df['Reviews'] > df['Installs']]
    print(f"Found {len(invalid)} records with reviews > installs")
    
    if len(invalid) > 0:
        print("\nSample of invalid records:")
        print(invalid[['App', 'Reviews', 'Installs']].head())
    
    df = df[df['Reviews'] <= df['Installs']]
    return df

df_clean = clean_reviews_installs(df_clean)
# Out:
# Dropped 0 rows with missing values
# Found 7 records with reviews > installs
#
# Sample of invalid records:
#                                 App  Reviews  Installs
# 2454            KBA-EZ Health Guide        4         1
# 4663  Alarmy (Sleep If U Can) - Pro    10249     10000
# 5917                       Ra Ga Ba        2         1
# 6700               Brick Breaker BR        7         5
# 7402           Trovami se ci riesci       11        10

# %%
invalid_prices = df_clean[(df_clean['Type'] == 'Free') & (df_clean['Price'] > 0)]
print(f"Free apps with price > 0: {len(invalid_prices)}")
df_clean = df_clean[~((df_clean['Type'] == 'Free') & (df_clean['Price'] > 0))]
# Out:
# Free apps with price > 0: 0

# %%
df_clean
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import os

# %%
# 1. First perform all your cleaning steps
# (Include all the cleaning code you've done so far)

# 2. Save the cleaned data to a CSV file
output_file = 'google_play_store_cleaned.csv'
df_clean.to_csv(output_file, index=False, encoding='utf-8')

# 3. Verify the file was created
import os
print(f"File saved successfully at: {os.path.abspath(output_file)}")
print(f"File size: {os.path.getsize(output_file)/1024:.2f} KB")
# Out:
# File saved successfully at: c:\Users\auxte\OneDrive\Desktop\GIT\python\Python-pandas\DA_assign\google_play_store_cleaned.csv
# File size: 1125.22 KB

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_clean['Price'])
plt.title('Boxplot of App Prices')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_clean['Reviews'])
plt.title('Boxplot of App Reviews')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_clean['Rating'], bins=20, kde=True)
plt.title('Distribution of App Ratings')
plt.show()

# %%
high_price = df_clean[df_clean['Price'] > 200]
print(f"Apps with price > $200: {len(high_price)}")
print(high_price[['App', 'Category', 'Price']])

# Drop apps with price > $200
df_clean = df_clean[df_clean['Price'] <= 200]
# Out:
# Apps with price > $200: 15
#                                  App   Category   Price
# 4197          most expensive app (H)     FAMILY  399.99
# 4362                      💎 I'm rich  LIFESTYLE  399.99
# 4367        I'm Rich - Trump Edition  LIFESTYLE  400.00
# 5351                       I am rich  LIFESTYLE  399.99
# 5354                  I am Rich Plus     FAMILY  399.99
# 5355                   I am rich VIP  LIFESTYLE  299.99
# 5356               I Am Rich Premium    FINANCE  399.99
# 5357             I am extremely Rich  LIFESTYLE  379.99
# 5358                      I am Rich!    FINANCE  399.99
# 5359              I am rich(premium)    FINANCE  399.99
# 5362                   I Am Rich Pro     FAMILY  399.99
# 5364  I am rich (Most expensive app)    FINANCE  399.99
# 5366                       I Am Rich     FAMILY  389.99
# 5369                       I am Rich    FINANCE  399.99
# 5373              I AM RICH PRO PLUS    FINANCE  399.99

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_clean['Price'])
plt.title('Boxplot of App Prices')
plt.show()

# %%
# Drop apps with more than 2 million reviews
df_clean = df_clean[df_clean['Reviews'] <= 2000000]

# %%
# Calculate percentiles
percentiles = df_clean['Installs'].quantile([0.1, 0.25, 0.5, 0.7, 0.9, 0.95, 0.99])
print("Install percentiles:")
print(percentiles)

# Drop apps above 99th percentile
install_threshold = df_clean['Installs'].quantile(0.99)
df_clean = df_clean[df_clean['Installs'] <= install_threshold]
# Out:
# Install percentiles:
# 0.10         1000.0
# 0.25        10000.0
# 0.50       500000.0
# 0.70      1000000.0
# 0.90     10000000.0
# 0.95     10000000.0
# 0.99    100000000.0
# Name: Installs, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_clean['Reviews'])
plt.title('Boxplot of App Reviews')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.jointplot(x='Price', y='Rating', data=df_clean, kind='scatter', alpha=0.5)
plt.suptitle('Rating vs. Price', y=1.02)
plt.show()

# %%
def clean_and_plot_size_vs_rating(df):
    # Convert to numeric
    df['Size'] = pd.to_numeric(df['Size'], errors='coerce')
    df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
    
    # Remove invalid/missing data
    plot_data = df.dropna(subset=['Size', 'Rating'])
    
    # Check data ranges
    print(f"Size range: {plot_data['Size'].min():.2f} to {plot_data['Size'].max():.2f} MB")
    print(f"Rating range: {plot_data['Rating'].min():.2f} to {plot_data['Rating'].max():.2f}")
    
    # Create plot
    plt.figure(figsize=(10,6))
    sns.jointplot(
        x='Size', 
        y='Rating', 
        data=plot_data, 
        kind='hex',
        xlim=(0, plot_data['Size'].quantile(0.95)),  # Show up to 95th percentile
        ylim=(1, 5)  # Rating scale
    )
    plt.suptitle('Rating vs. App Size (MB)', y=1.02)
    plt.show()
    
    return plot_data

cleaned_data = clean_and_plot_size_vs_rating(df_clean)
# Out:
# Size range: 0.01 to 100.00 MB
# Rating range: 1.00 to 5.00

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x='Category', y='Rating', data=df_clean)
plt.title('Rating Distribution by App Category', pad=20)
plt.xticks(rotation=90)
plt.show()

# %%
inp1=df_clean.copy()

# %%
inp1.Installs.describe()
# Out:
# count    8.865000e+03
# mean     4.815078e+06
# std      1.415604e+07
# min      5.000000e+00
# 25%      1.000000e+04
# 50%      5.000000e+05
# 75%      5.000000e+06
# max      1.000000e+08
# Name: Installs, dtype: float64

# %%
inp1.Installs = inp1.Installs.apply(np.log1p)

# %%
inp1.Reviews = inp1.Reviews.apply(np.log1p)

# %%
inp1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
inp1.drop(["App","Last Updated","Current Ver","Android Ver"],axis=1, inplace=True)

# %%
inp1.shape
# Out:
# (8865, 9)

# %%
inp2 = pd.get_dummies(inp1, drop_first = True)

# %%
inp2.columns
# Out:
# Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price',
#        'Category_AUTO_AND_VEHICLES', 'Category_BEAUTY',
#        'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS', 'Category_COMICS',
#        ...
#        'Genres_Tools', 'Genres_Tools;Education', 'Genres_Travel & Local',
#        'Genres_Travel & Local;Action & Adventure', 'Genres_Trivia',
#        'Genres_Video Players & Editors',
#        'Genres_Video Players & Editors;Creativity',
#        'Genres_Video Players & Editors;Music & Video', 'Genres_Weather',
#        'Genres_Word'],
#       dtype='object', length=157)

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(inp2, train_size=0.7, random_state = 100)

# %%
df_train.shape, df_test.shape
# Out:
# ((6205, 157), (2660, 157))

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
print("Initial shapes:")
print(f"Training set: {df_train.shape}")  
print(f"Test set: {df_test.shape}")
# Out:
# Initial shapes:
# Training set: (6205, 156)
# Test set: (2660, 156)
